# %% [markdown]
# # DSBDAL2_DataWranglingII

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df.shape
# Out:
# (1001, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %% [markdown]
# ## Handling Missing Data

# %% [markdown]
# ### isnull()

# %%
df.isnull()
# Out:
#       Roll No   Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0       False  False      False      False      False      False       False
# 1       False  False      False      False      False       True       False
# 2       False  False      False      False      False      False       False
# 3       False  False      False      False       True      False       False
# 4       False  False      False      False      False      False       False
# ...       ...    ...        ...        ...        ...        ...         ...
# 996     False  False      False      False      False      False       False
# 997     False  False      False      False      False      False       False
# 998     False  False      False      False      False      False       False
# 999     False  False      False      False      False      False       False
# 1000    False  False      False      False      False      False       False
#
# [1001 rows x 7 columns]

# %%
## to find total null values is each column
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %% [markdown]
# ### notnull()

# %%
df.notnull()
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df.notnull().sum()
# Out:
# Roll No       1001
# Name          1001
# Subject 1     1001
# Subject 2     1001
# Subject 3     1000
# Subject 4     1000
# Attendance    1001
# dtype: int64

# %% [markdown]
# ## Handling the missing values

# %% [markdown]
# ### fillna()

# %%
df.fillna(0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.fillna(50,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0       50.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       50.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.fillna(method='pad')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       71.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.fillna(method='bfill')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0       99.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       84.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %% [markdown]
# ### interpolate()

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.interpolate(method='linear',limit_direction = 'forward')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0       95.5
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       77.5       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df['Subject 3'].fillna(df['Subject 3'].mean(),inplace=True)
df['Subject 4'].fillna(df['Subject 4'].mean(),inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62      73.00     92.000  \
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     0
# Subject 4     0
# Attendance    0
# dtype: int64

# %% [markdown]
# ### replace()

# %%
df.replace(to_replace=np.nan,value=df['Subject 3'].mean(),inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62      73.00     92.000  \
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %% [markdown]
# ## Drop Missing Values

# %%
df = pd.read_csv("A1.csv")
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.dropna()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
df.shape
# Out:
# (1001, 7)

# %%
## in a row if all features have null value then drop
df.dropna(how='all',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
## any value null drop
df.dropna(how='any',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
## drop column
df.dropna(axis=1)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %% [markdown]
# ## Check for negative Values

# %%
df[df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']]<0]
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 5         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 6         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [999 rows x 7 columns]

# %%
df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']] = df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']].clip(lower=0)

# %%
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0           1     Student_1        100         62       73.0       92.0  \
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2              0
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %% [markdown]
# ## Handling Inconsistencies - Duplicate Data

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0          1     Student_1        100         62       73.0       92.0  \
# 2          3     Student_3        100         88       71.0       99.0
# 4          5     Student_5         97         70       84.0       70.0
# 5          6     Student_6         98         76       89.0       92.0
# 6          7     Student_7         61         64       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 2             0
# 4            86
# 5            82
# 6            83
# ..          ...
# 995          87
# 996          98
# 997          83
# 998          90
# 999          79
#
# [998 rows x 7 columns]

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# ### Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nc = ['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
nc
# Out:
# ['Subject 1', 'Subject 2', 'Subject 3', 'Subject 4', 'Attendance']

# %%
for col in nc:
    sns.boxplot(df[col])
    plt.title(f'boxplot of {col}')
    plt.show()

# %%
for column in nc:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=df, x=df.index, y=column, label=column)
    
    plt.title(f'Scatter Plot - {column}')
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
for col in nc:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3-Q1
    lb = Q1 - 1.5*IQR
    ub = Q3 + 1.5*IQR
    df[col] = np.where((df[col]<lb) | (df[col]>ub),df[col].median(),df[col])

df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0          1     Student_1      100.0       62.0       73.0       92.0  \
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance
# 0          96.0
# 2          86.0
# 4          86.0
# 5          82.0
# 6          83.0
# ..          ...
# 995        87.0
# 996        98.0
# 997        83.0
# 998        90.0
# 999        79.0
#
# [998 rows x 7 columns]

# %%
dfz = pd.read_csv('A1.csv')

# %%
#z-score manually
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    median_value = data.median()
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            i = median_value
    return data

for feat in nc:
    detect_outliers_zscore(dfz[feat])

# %% [markdown]
# ### Skewness

# %%
from scipy.stats import skew

for col in nc:
    skewness = skew(df[col])
    print(f"Skewness of {col}: {skewness}")
# Out:
# Skewness of Subject 1: 0.08854305280754458
# Skewness of Subject 2: -0.009707975611008859
# Skewness of Subject 3: 0.004967632869006547
# Skewness of Subject 4: -0.035664011006138696
# Skewness of Attendance: -0.09253182297757746

# %% [markdown]
# ## Data Transformation

# %%
df['log_attendence'] = np.log1p(df['Attendance'])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0          1     Student_1      100.0       62.0       73.0       92.0  \
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence
# 0          96.0        4.574711
# 2          86.0        4.465908
# 4          86.0        4.465908
# 5          82.0        4.418841
# 6          83.0        4.430817
# ..          ...             ...
# 995        87.0        4.477337
# 996        98.0        4.595120
# 997        83.0        4.430817
# 998        90.0        4.510860
# 999        79.0        4.382027
#
# [998 rows x 8 columns]

# %%
df['sqrt_attendence'] = np.sqrt(df['Attendance'])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0          1     Student_1      100.0       62.0       73.0       92.0  \
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence  sqrt_attendence
# 0          96.0        4.574711         9.797959
# 2          86.0        4.465908         9.273618
# 4          86.0        4.465908         9.273618
# 5          82.0        4.418841         9.055385
# 6          83.0        4.430817         9.110434
# ..          ...             ...              ...
# 995        87.0        4.477337         9.327379
# 996        98.0        4.595120         9.899495
# 997        83.0        4.430817         9.110434
# 998        90.0        4.510860         9.486833
# 999        79.0        4.382027         8.888194
#
# [998 rows x 9 columns]

# %%
df['cbrt_Attendance'] = np.cbrt(df['Attendance'])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0          1     Student_1      100.0       62.0       73.0       92.0  \
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence  sqrt_attendence  cbrt_Attendance
# 0          96.0        4.574711         9.797959         4.578857
# 2          86.0        4.465908         9.273618         4.414005
# 4          86.0        4.465908         9.273618         4.414005
# 5          82.0        4.418841         9.055385         4.344481
# 6          83.0        4.430817         9.110434         4.362071
# ..          ...             ...              ...              ...
# 995        87.0        4.477337         9.327379         4.431048
# 996        98.0        4.595120         9.899495         4.610436
# 997        83.0        4.430817         9.110434         4.362071
# 998        90.0        4.510860         9.486833         4.481405
# 999        79.0        4.382027         8.888194         4.290840
#
# [998 rows x 10 columns]

# %% [markdown]
# ## Insert New Column

# %%
data = {'Value': np.random.randn(df.shape[0])}  # Example data, you can replace it with your own
df_div = pd.DataFrame(data)
categories = ['A', 'B', 'C', 'D']
df_div['Div'] = np.random.choice(categories, size=len(df))

# %%
merged_df = pd.concat([df, df_div], axis=1)
merged_df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0        1.0     Student_1      100.0       62.0       73.0       92.0  \
# 2        3.0     Student_3      100.0       88.0       71.0       99.0
# 4        5.0     Student_5       97.0       70.0       84.0       70.0
# 5        6.0     Student_6       98.0       76.0       89.0       92.0
# 6        7.0     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 997    998.0   Student_998       61.0       96.0       62.0       84.0
# 998    999.0   Student_999       72.0       76.0       90.0       72.0
# 999   1000.0  Student_1000       68.0       87.0      100.0       76.0
# 1        NaN           NaN        NaN        NaN        NaN        NaN
# 3        NaN           NaN        NaN        NaN        NaN        NaN
#
#      Attendance  log_attendence  sqrt_attendence  cbrt_Attendance     Value
# 0          96.0        4.574711         9.797959         4.578857  0.112867  \
# 2          86.0        4.465908         9.273618         4.414005 -0.699154
# 4          86.0        4.465908         9.273618         4.414005 -1.428083
# 5          82.0        4.418841         9.055385         4.344481 -0.124623
# 6          83.0        4.430817         9.110434         4.362071 -0.119199
# ..          ...             ...              ...              ...       ...
# 997        83.0        4.430817         9.110434         4.362071 -0.760646
# 998        90.0        4.510860         9.486833         4.481405       NaN
# 999        79.0        4.382027         8.888194         4.290840       NaN
# 1           NaN             NaN              NaN              NaN -0.901472
# 3           NaN             NaN              NaN              NaN  0.495730
#
#      Div
# 0      D
# 2      B
# 4      D
# 5      B
# 6      D
# ..   ...
# 997    B
# 998  NaN
# 999  NaN
# 1      B
# 3      C
#
# [1000 rows x 12 columns]

# %%
merged_df = merged_df[:-2]
merged_df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0        1.0     Student_1      100.0       62.0       73.0       92.0  \
# 2        3.0     Student_3      100.0       88.0       71.0       99.0
# 4        5.0     Student_5       97.0       70.0       84.0       70.0
# 5        6.0     Student_6       98.0       76.0       89.0       92.0
# 6        7.0     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995    996.0   Student_996       74.0       89.0       85.0       71.0
# 996    997.0   Student_997       88.0       68.0       84.0       66.0
# 997    998.0   Student_998       61.0       96.0       62.0       84.0
# 998    999.0   Student_999       72.0       76.0       90.0       72.0
# 999   1000.0  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence  sqrt_attendence  cbrt_Attendance     Value
# 0          96.0        4.574711         9.797959         4.578857  0.112867  \
# 2          86.0        4.465908         9.273618         4.414005 -0.699154
# 4          86.0        4.465908         9.273618         4.414005 -1.428083
# 5          82.0        4.418841         9.055385         4.344481 -0.124623
# 6          83.0        4.430817         9.110434         4.362071 -0.119199
# ..          ...             ...              ...              ...       ...
# 995        87.0        4.477337         9.327379         4.431048  1.558786
# 996        98.0        4.595120         9.899495         4.610436 -0.592242
# 997        83.0        4.430817         9.110434         4.362071 -0.760646
# 998        90.0        4.510860         9.486833         4.481405       NaN
# 999        79.0        4.382027         8.888194         4.290840       NaN
#
#      Div
# 0      D
# 2      B
# 4      D
# 5      B
# 6      D
# ..   ...
# 995    D
# 996    B
# 997    B
# 998  NaN
# 999  NaN
#
# [998 rows x 12 columns]

# %%
merged_df['Div'] = merged_df['Div'].fillna(merged_df['Div'].mode())

merged_df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25024\1273381511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['Div'] = merged_df['Div'].fillna(merged_df['Div'].mode())
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0        1.0     Student_1      100.0       62.0       73.0       92.0  \
# 2        3.0     Student_3      100.0       88.0       71.0       99.0
# 4        5.0     Student_5       97.0       70.0       84.0       70.0
# 5        6.0     Student_6       98.0       76.0       89.0       92.0
# 6        7.0     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995    996.0   Student_996       74.0       89.0       85.0       71.0
# 996    997.0   Student_997       88.0       68.0       84.0       66.0
# 997    998.0   Student_998       61.0       96.0       62.0       84.0
# 998    999.0   Student_999       72.0       76.0       90.0       72.0
# 999   1000.0  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence  sqrt_attendence  cbrt_Attendance     Value
# 0          96.0        4.574711         9.797959         4.578857  0.112867  \
# 2          86.0        4.465908         9.273618         4.414005 -0.699154
# 4          86.0        4.465908         9.273618         4.414005 -1.428083
# 5          82.0        4.418841         9.055385         4.344481 -0.124623
# 6          83.0        4.430817         9.110434         4.362071 -0.119199
# ..          ...             ...              ...              ...       ...
# 995        87.0        4.477337         9.327379         4.431048  1.558786
# 996        98.0        4.595120         9.899495         4.610436 -0.592242
# 997        83.0        4.430817         9.110434         4.362071 -0.760646
# 998        90.0        4.510860         9.486833         4.481405       NaN
# 999        79.0        4.382027         8.888194         4.290840       NaN
#
#      Div
# 0      D
# 2      B
# 4      D
# 5      B
# 6      D
# ..   ...
# 995    D
# 996    B
# 997    B
# 998  NaN
# 999  NaN
#
# [998 rows x 12 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
#Performing Onehot Encoding
encoded_df = pd.get_dummies(merged_df['Div'])

# %%
merged_df = pd.concat([merged_df, encoded_df], axis=1)

# %%
merged_df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4
# 0        1.0     Student_1      100.0       62.0       73.0       92.0  \
# 2        3.0     Student_3      100.0       88.0       71.0       99.0
# 4        5.0     Student_5       97.0       70.0       84.0       70.0
# 5        6.0     Student_6       98.0       76.0       89.0       92.0
# 6        7.0     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995    996.0   Student_996       74.0       89.0       85.0       71.0
# 996    997.0   Student_997       88.0       68.0       84.0       66.0
# 997    998.0   Student_998       61.0       96.0       62.0       84.0
# 998    999.0   Student_999       72.0       76.0       90.0       72.0
# 999   1000.0  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  log_attendence  sqrt_attendence  cbrt_Attendance     Value
# 0          96.0        4.574711         9.797959         4.578857  0.112867  \
# 2          86.0        4.465908         9.273618         4.414005 -0.699154
# 4          86.0        4.465908         9.273618         4.414005 -1.428083
# 5          82.0        4.418841         9.055385         4.344481 -0.124623
# 6          83.0        4.430817         9.110434         4.362071 -0.119199
# ..          ...             ...              ...              ...       ...
# 995        87.0        4.477337         9.327379         4.431048  1.558786
# 996        98.0        4.595120         9.899495         4.610436 -0.592242
# 997        83.0        4.430817         9.110434         4.362071 -0.760646
# 998        90.0        4.510860         9.486833         4.481405       NaN
# 999        79.0        4.382027         8.888194         4.290840       NaN
#
#      Div      A      B      C      D
# 0      D  False  False  False   True
# 2      B  False   True  False  False
# 4      D  False  False  False   True
# 5      B  False   True  False  False
# 6      D  False  False  False   True
# ..   ...    ...    ...    ...    ...
# 995    D  False  False  False   True
# 996    B  False   True  False  False
# 997    B  False   True  False  False
# 998  NaN  False  False  False  False
# 999  NaN  False  False  False  False
#
# [998 rows x 16 columns]
